# %% [markdown]
# # Relatório de análise V

# %% [markdown]
# ## Tratamento de dados

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22155  Apartamento                 Méier        2      0       0    70
# 22156    Quitinete                Centro        0      0       0    27
# 22157  Apartamento           Jacarepaguá        3      1       2    78
# 22158  Apartamento  São Francisco Xavier        2      1       0    48
# 22159  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 22155   900.0       490.0  48.0
# 22156   800.0       350.0  25.0
# 22157  1800.0       800.0  40.0
# 22158  1400.0       509.0  37.0
# 22159  3000.0       760.0   0.0
#
# [22160 rows x 9 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22160 entries, 0 to 22159
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22160 non-null  object
#  1   Bairro      22160 non-null  object
#  2   Quartos     22160 non-null  int64
#  3   Vagas       22160 non-null  int64
#  4   Suites      22160 non-null  int64
#  5   Area        22160 non-null  int64
#  6   Valor       22160 non-null  float64
#  7   Condominio  22160 non-null  float64
#  8   IPTU        22160 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ MB

# %%
selecao_valor = (dados['Valor'].notnull())
filtro_valor = dados[selecao_valor]
valor_filtrado = dados[selecao_valor].shape[0]
dados = dados[selecao_valor]
dados.shape[0]
# Out:
# 22160

# %%
selecao_condominio_invalido = ((dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull())) | ((dados['Tipo'] == 'Quitinete') & (dados['Condominio'].isnull())) | ((dados['Tipo'] == 'Casa de Condomínio') & (dados['Condominio'].isnull())) | ((dados['Tipo'] == 'Flat') & (dados['Condominio'].isnull())) | ((dados['Tipo'] == 'Loft') & (dados['Condominio'].isnull())) | ((dados['Tipo'] == 'Studio') & (dados['Condominio'].isnull()))
dados = dados[~selecao_condominio_invalido]

# %%
dados.shape[0]
# Out:
# 22160

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Apartamento',
#  'Flat',
#  'Casa de Condomínio',
#  'Casa de Vila',
#  'Loft',
#  'Chácara',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio']

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22155  Apartamento                 Méier        2      0       0    70
# 22156    Quitinete                Centro        0      0       0    27
# 22157  Apartamento           Jacarepaguá        3      1       2    78
# 22158  Apartamento  São Francisco Xavier        2      1       0    48
# 22159  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 22155   900.0       490.0  48.0
# 22156   800.0       350.0  25.0
# 22157  1800.0       800.0  40.0
# 22158  1400.0       509.0  37.0
# 22159  3000.0       760.0   0.0
#
# [22160 rows x 9 columns]

# %%
dados['IPTU'].fillna(0, inplace = True)

# %%
dados['Condominio'].fillna(0, inplace = True)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22155  Apartamento                 Méier        2      0       0    70
# 22156    Quitinete                Centro        0      0       0    27
# 22157  Apartamento           Jacarepaguá        3      1       2    78
# 22158  Apartamento  São Francisco Xavier        2      1       0    48
# 22159  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 22155   900.0       490.0  48.0
# 22156   800.0       350.0  25.0
# 22157  1800.0       800.0  40.0
# 22158  1400.0       509.0  37.0
# 22159  3000.0       760.0   0.0
#
# [22160 rows x 9 columns]

# %%
dados.index = range(len(dados))

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22155  Apartamento                 Méier        2      0       0    70
# 22156    Quitinete                Centro        0      0       0    27
# 22157  Apartamento           Jacarepaguá        3      1       2    78
# 22158  Apartamento  São Francisco Xavier        2      1       0    48
# 22159  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 22155   900.0       490.0  48.0
# 22156   800.0       350.0  25.0
# 22157  1800.0       800.0  40.0
# 22158  1400.0       509.0  37.0
# 22159  3000.0       760.0   0.0
#
# [22160 rows x 9 columns]

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep = ';', index = False)

# %%
dados1 = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados1
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento              Cachambi        2      0       0    50
# ...            ...                   ...      ...    ...     ...   ...
# 22155  Apartamento                 Méier        2      0       0    70
# 22156    Quitinete                Centro        0      0       0    27
# 22157  Apartamento           Jacarepaguá        3      1       2    78
# 22158  Apartamento  São Francisco Xavier        2      1       0    48
# 22159  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# 2       800.0       390.0  20.0
# 3       800.0       230.0   0.0
# 4      1300.0       301.0  17.0
# ...       ...         ...   ...
# 22155   900.0       490.0  48.0
# 22156   800.0       350.0  25.0
# 22157  1800.0       800.0  40.0
# 22158  1400.0       509.0  37.0
# 22159  3000.0       760.0   0.0
#
# [22160 rows x 9 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22160 entries, 0 to 22159
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22160 non-null  object
#  1   Bairro      22160 non-null  object
#  2   Quartos     22160 non-null  int64
#  3   Vagas       22160 non-null  int64
#  4   Suites      22160 non-null  int64
#  5   Area        22160 non-null  int64
#  6   Valor       22160 non-null  float64
#  7   Condominio  22160 non-null  float64
#  8   IPTU        22160 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.5+ MB
